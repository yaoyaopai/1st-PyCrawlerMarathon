# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11026778053","type":"CreateEvent","actor":{"id":54757523,"login":"mxk180040","display_login":"mxk180040","gravatar_id":"","url":"https://api.github.com/users/mxk180040","avatar_url":"https://avatars.githubusercontent.com/u/54757523?"},"repo":{"id":226274030,"name":"mxk180040/Customer-Churn-Analytics","url":"https://api.github.com/repos/mxk180040/Customer-Churn-Analytics"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"Customer attrition, also known as customer churn, customer turnover, or customer defection, is the loss of clients or customers. Telephone service companies, Internet service providers, pay TV companies, insurance firms, and alarm monitoring services, often use customer attrition analysis and customer attrition rates as one of their key business metrics because the cost of retaining an existing customer is far less than acquiring a new one. ","pusher_type":"user"},"public":true,"created_at":"2019-12-06T07:46:09Z"},{"id":"11026778051","type":"ForkEvent","actor":{"id":10758986,"login":"shuying136","display_login":"shuying136","gravatar_id":"","url":"https://api.github.com/users/shuying136","avatar_url":"https://avatars.githubusercontent.com/u/10758986?"},"repo":{"id":152715619,"name":"CrazyHZM/dubbo","url":"https://api.github.com/repos/CrazyHZM/dubbo"},"payload":{"forkee":{"id":226274031,"node_id":"MDEwOlJlcG9zaXRvcnkyMjYyNzQwMzE=","name":"dubbo","full_name":"shuying136/dubbo","private":false,"owner":{"login":"shuying136","id":10758986,"node_id":"MDQ6VXNlcjEwNzU4OTg2","avatar_url":"https://avatars2.githubusercontent.com/u/10758986?v=4","gravatar_id":"","url":"https://api.github.com/users/shuying136","html_url":"https://github.com/shuying136","followers_url":"https://api.github.com/users/shuying136/followers","following_url":"https://api.github.com/users/shuying136/following{/other_user}","gists_url":"https://api.github.com/users/shuying136/gists{/gist_id}","starred_url":"https://api.github.com/users/shuying136/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/shuying136/subscriptions","organizations_url":"https://api.github.com/users/shuying136/orgs","repos_url":"https://api.github.com/users/shuying136/repos","events_url":"https://api.github.com/users/shuying136/events{/privacy}","received_events_url":"https://api.github.com/users/shuying136/received_events","type":"User","site_admin":false},"html_url":"https://github.com/shuying136/dubbo","description":"Apache Dubbo (incubating) is a high-performance, java based, open source RPC framework.","fork":true,"url":"https://api.github.com/repos/shuying136/dubbo","forks_url":"https://api.github.com/repos/shuying136/dubbo/forks","keys_url":"https://api.github.com/repos/shuying136/dubbo/keys{/key_id}","collaborators_url":"https://api.github.com/repos/shuying136/dubbo/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/shuying136/dubbo/teams","hooks_url":"https://api.github.com/repos/shuying136/dubbo/hooks","issue_events_url":"https://api.github.com/repos/shuying136/dubbo/issues/events{/number}","events_url":"https://api.github.com/repos/shuying136/dubbo/events","assignees_url":"https://api.github.com/repos/shuying136/dubbo/assignees{/user}","branches_url":"https://api.github.com/repos/shuying136/dubbo/branches{/branch}","tags_url":"https://api.github.com/repos/shuying136/dubbo/tags","blobs_url":"https://api.github.com/repos/shuying136/dubbo/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/shuying136/dubbo/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/shuying136/dubbo/git/refs{/sha}","trees_url":"https://api.github.com/repos/shuying136/dubbo/git/trees{/sha}","statuses_url":"https://api.github.com/repos/shuying136/dubbo/statuses/{sha}","languages_url":"https://api.github.com/repos/shuying136/dubbo/languages","stargazers_url":"https://api.github.com/repos/shuying136/dubbo/stargazers","contributors_url":"https://api.github.com/repos/shuying136/dubbo/contributo ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11026778053',
#   'type': 'CreateEvent',
#   'actor': {'id': 54757523,
#    'login': 'mxk180040',
#    'display_login': 'mxk180040',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mxk180040',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54757523?'},
#   'repo': {'id': 226274030,
#    'name': 'mxk180040/Customer-Churn-Analytics',
#    'url': 'https://api.github.com/repos/mxk180040/Customer-Churn-Analytics'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Customer attrition, also known as customer churn, customer turnover, or customer defection, is the loss of clients or customers. Telephone service companies, Internet service providers, pay TV companies, insurance firms, and alarm monitoring services, often use customer attrition analysis and customer attrition rates as one of their key business metrics because the cost of retaining an existing customer is far less than acquiring a new one. ',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778051',
#   'type': 'ForkEvent',
#   'actor': {'id': 10758986,
#    'login': 'shuying136',
#    'display_login': 'shuying136',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shuying136',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10758986?'},
#   'repo': {'id': 152715619,
#    'name': 'CrazyHZM/dubbo',
#    'url': 'https://api.github.com/repos/CrazyHZM/dubbo'},
#   'payload': {'forkee': {'id': 226274031,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYyNzQwMzE=',
#     'name': 'dubbo',
#     'full_name': 'shuying136/dubbo',
#     'private': False,
#     'owner': {'login': 'shuying136',
#      'id': 10758986,
#      'node_id': 'MDQ6VXNlcjEwNzU4OTg2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/10758986?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shuying136',
#      'html_url': 'https://github.com/shuying136',
#      'followers_url': 'https://api.github.com/users/shuying136/followers',
#      'following_url': 'https://api.github.com/users/shuying136/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shuying136/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shuying136/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shuying136/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shuying136/orgs',
#      'repos_url': 'https://api.github.com/users/shuying136/repos',
#      'events_url': 'https://api.github.com/users/shuying136/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shuying136/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/shuying136/dubbo',
#     'description': 'Apache Dubbo (incubating) is a high-performance, java based, open source RPC framework.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/shuying136/dubbo',
#     'forks_url': 'https://api.github.com/repos/shuying136/dubbo/forks',
#     'keys_url': 'https://api.github.com/repos/shuying136/dubbo/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/shuying136/dubbo/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/shuying136/dubbo/teams',
#     'hooks_url': 'https://api.github.com/repos/shuying136/dubbo/hooks',
#     'issue_events_url': 'https://api.github.com/repos/shuying136/dubbo/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/shuying136/dubbo/events',
#     'assignees_url': 'https://api.github.com/repos/shuying136/dubbo/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/shuying136/dubbo/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/shuying136/dubbo/tags',
#     'blobs_url': 'https://api.github.com/repos/shuying136/dubbo/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/shuying136/dubbo/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/shuying136/dubbo/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/shuying136/dubbo/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/shuying136/dubbo/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/shuying136/dubbo/languages',
#     'stargazers_url': 'https://api.github.com/repos/shuying136/dubbo/stargazers',
#     'contributors_url': 'https://api.github.com/repos/shuying136/dubbo/contributors',
#     'subscribers_url': 'https://api.github.com/repos/shuying136/dubbo/subscribers',
#     'subscription_url': 'https://api.github.com/repos/shuying136/dubbo/subscription',
#     'commits_url': 'https://api.github.com/repos/shuying136/dubbo/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/shuying136/dubbo/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/shuying136/dubbo/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/shuying136/dubbo/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/shuying136/dubbo/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/shuying136/dubbo/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/shuying136/dubbo/merges',
#     'archive_url': 'https://api.github.com/repos/shuying136/dubbo/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/shuying136/dubbo/downloads',
#     'issues_url': 'https://api.github.com/repos/shuying136/dubbo/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/shuying136/dubbo/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/shuying136/dubbo/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/shuying136/dubbo/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/shuying136/dubbo/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/shuying136/dubbo/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/shuying136/dubbo/deployments',
#     'created_at': '2019-12-06T07:46:09Z',
#     'updated_at': '2019-11-14T11:37:11Z',
#     'pushed_at': '2019-11-29T13:01:50Z',
#     'git_url': 'git://github.com/shuying136/dubbo.git',
#     'ssh_url': 'git@github.com:shuying136/dubbo.git',
#     'clone_url': 'https://github.com/shuying136/dubbo.git',
#     'svn_url': 'https://github.com/shuying136/dubbo',
#     'homepage': 'http://dubbo.incubator.apache.org',
#     'size': 26410,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'apache-2.0',
#      'name': 'Apache License 2.0',
#      'spdx_id': 'Apache-2.0',
#      'url': 'https://api.github.com/licenses/apache-2.0',
#      'node_id': 'MDc6TGljZW5zZTI='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778057',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 141252,
#    'login': 'fthomas',
#    'display_login': 'fthomas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fthomas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/141252?'},
#   'repo': {'id': 52904323,
#    'name': 'fthomas/refined-sjs-example',
#    'url': 'https://api.github.com/repos/fthomas/refined-sjs-example'},
#   'payload': {'action': 'closed',
#    'number': 50,
#    'pull_request': {'url': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50',
#     'id': 326840689,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzI2ODQwNjg5',
#     'html_url': 'https://github.com/fthomas/refined-sjs-example/pull/50',
#     'diff_url': 'https://github.com/fthomas/refined-sjs-example/pull/50.diff',
#     'patch_url': 'https://github.com/fthomas/refined-sjs-example/pull/50.patch',
#     'issue_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/50',
#     'number': 50,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Update sbt-scalafmt to 2.0.6',
#     'user': {'login': 'scala-steward',
#      'id': 43047562,
#      'node_id': 'MDQ6VXNlcjQzMDQ3NTYy',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/43047562?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/scala-steward',
#      'html_url': 'https://github.com/scala-steward',
#      'followers_url': 'https://api.github.com/users/scala-steward/followers',
#      'following_url': 'https://api.github.com/users/scala-steward/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/scala-steward/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/scala-steward/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/scala-steward/subscriptions',
#      'organizations_url': 'https://api.github.com/users/scala-steward/orgs',
#      'repos_url': 'https://api.github.com/users/scala-steward/repos',
#      'events_url': 'https://api.github.com/users/scala-steward/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/scala-steward/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Updates org.scalameta:sbt-scalafmt from 2.0.4 to 2.0.6.\n\n\nI\'ll automatically update this PR to resolve conflicts as long as you don\'t change it yourself.\n\nIf you\'d like to skip this version, you can just close this PR. If you have any feedback, just mention me in the comments below.\n\nHave a fantastic day writing Scala!\n\n<details>\n<summary>Ignore future updates</summary>\n\nAdd this to your `.scala-steward.conf` file to ignore future updates of this dependency:\n```\nupdates.ignore = [ { groupId = "org.scalameta", artifactId = "sbt-scalafmt" } ]\n```\n</details>\n\nlabels: semver-patch',
#     'created_at': '2019-10-10T17:07:49Z',
#     'updated_at': '2019-12-06T07:46:08Z',
#     'closed_at': '2019-12-06T07:46:08Z',
#     'merged_at': None,
#     'merge_commit_sha': 'acec1629e6e70bb2961ae9e24ef50ba20bb9e40b',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50/commits',
#     'review_comments_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50/comments',
#     'review_comment_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/50/comments',
#     'statuses_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/statuses/f4dea16c991e866f345bf678e1af2f2008c7a5f2',
#     'head': {'label': 'scala-steward:update/sbt-scalafmt-2.0.6',
#      'ref': 'update/sbt-scalafmt-2.0.6',
#      'sha': 'f4dea16c991e866f345bf678e1af2f2008c7a5f2',
#      'user': {'login': 'scala-steward',
#       'id': 43047562,
#       'node_id': 'MDQ6VXNlcjQzMDQ3NTYy',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/43047562?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/scala-steward',
#       'html_url': 'https://github.com/scala-steward',
#       'followers_url': 'https://api.github.com/users/scala-steward/followers',
#       'following_url': 'https://api.github.com/users/scala-steward/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/scala-steward/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/scala-steward/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/scala-steward/subscriptions',
#       'organizations_url': 'https://api.github.com/users/scala-steward/orgs',
#       'repos_url': 'https://api.github.com/users/scala-steward/repos',
#       'events_url': 'https://api.github.com/users/scala-steward/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/scala-steward/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': None},
#     'base': {'label': 'fthomas:master',
#      'ref': 'master',
#      'sha': 'c4c054e7986d715ac05f727905018e48339dfaa6',
#      'user': {'login': 'fthomas',
#       'id': 141252,
#       'node_id': 'MDQ6VXNlcjE0MTI1Mg==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/141252?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fthomas',
#       'html_url': 'https://github.com/fthomas',
#       'followers_url': 'https://api.github.com/users/fthomas/followers',
#       'following_url': 'https://api.github.com/users/fthomas/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fthomas/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fthomas/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fthomas/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fthomas/orgs',
#       'repos_url': 'https://api.github.com/users/fthomas/repos',
#       'events_url': 'https://api.github.com/users/fthomas/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fthomas/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 52904323,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk1MjkwNDMyMw==',
#       'name': 'refined-sjs-example',
#       'full_name': 'fthomas/refined-sjs-example',
#       'private': False,
#       'owner': {'login': 'fthomas',
#        'id': 141252,
#        'node_id': 'MDQ6VXNlcjE0MTI1Mg==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/141252?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/fthomas',
#        'html_url': 'https://github.com/fthomas',
#        'followers_url': 'https://api.github.com/users/fthomas/followers',
#        'following_url': 'https://api.github.com/users/fthomas/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/fthomas/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/fthomas/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/fthomas/subscriptions',
#        'organizations_url': 'https://api.github.com/users/fthomas/orgs',
#        'repos_url': 'https://api.github.com/users/fthomas/repos',
#        'events_url': 'https://api.github.com/users/fthomas/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/fthomas/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/fthomas/refined-sjs-example',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/fthomas/refined-sjs-example',
#       'forks_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/forks',
#       'keys_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/teams',
#       'hooks_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/hooks',
#       'issue_events_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/events',
#       'assignees_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/tags',
#       'blobs_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/languages',
#       'stargazers_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/stargazers',
#       'contributors_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/contributors',
#       'subscribers_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/subscribers',
#       'subscription_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/subscription',
#       'commits_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/merges',
#       'archive_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/downloads',
#       'issues_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/fthomas/refined-sjs-example/deployments',
#       'created_at': '2016-03-01T19:37:04Z',
#       'updated_at': '2019-12-06T07:40:11Z',
#       'pushed_at': '2019-12-06T07:40:09Z',
#       'git_url': 'git://github.com/fthomas/refined-sjs-example.git',
#       'ssh_url': 'git@github.com:fthomas/refined-sjs-example.git',
#       'clone_url': 'https://github.com/fthomas/refined-sjs-example.git',
#       'svn_url': 'https://github.com/fthomas/refined-sjs-example',
#       'homepage': None,
#       'size': 87,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Scala',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 17,
#       'license': None,
#       'forks': 1,
#       'open_issues': 17,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50'},
#      'html': {'href': 'https://github.com/fthomas/refined-sjs-example/pull/50'},
#      'issue': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/50'},
#      'comments': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/issues/50/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/pulls/50/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/fthomas/refined-sjs-example/statuses/f4dea16c991e866f345bf678e1af2f2008c7a5f2'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': False,
#     'rebaseable': False,
#     'mergeable_state': 'dirty',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778050',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 79033337,
#    'name': 'Apollon77/ioBroker.smartmeter',
#    'url': 'https://api.github.com/repos/Apollon77/ioBroker.smartmeter'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/sentry/node-5.10.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778047',
#   'type': 'PushEvent',
#   'actor': {'id': 18025580,
#    'login': 'lilue',
#    'display_login': 'lilue',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lilue',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18025580?'},
#   'repo': {'id': 203349850,
#    'name': 'lilue/kindergarten',
#    'url': 'https://api.github.com/repos/lilue/kindergarten'},
#   'payload': {'push_id': 4363253945,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'edb96fe3eb64ecce89ae572504239a0890631c30',
#    'before': '34d6b467be094ae23af1aa43781a00ca8a3d0287',
#    'commits': [{'sha': 'edb96fe3eb64ecce89ae572504239a0890631c30',
#      'author': {'email': 'aa_0933@qq.com', 'name': 'lilue'},
#      'message': 'total_fee',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lilue/kindergarten/commits/edb96fe3eb64ecce89ae572504239a0890631c30'}]},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778058',
#   'type': 'PushEvent',
#   'actor': {'id': 44135362,
#    'login': 'Rits1272',
#    'display_login': 'Rits1272',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rits1272',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44135362?'},
#   'repo': {'id': 224998548,
#    'name': 'Rits1272/Timeline-wave',
#    'url': 'https://api.github.com/repos/Rits1272/Timeline-wave'},
#   'payload': {'push_id': 4363253948,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '47237adf9869f0003f9458e2c094de6e38e03b88',
#    'before': 'e4e273461cbe611f21b97e774ea5e8fc8d72f07d',
#    'commits': [{'sha': '47237adf9869f0003f9458e2c094de6e38e03b88',
#      'author': {'email': 'ritikjain1272@gmail.com', 'name': 'Ritik Jain'},
#      'message': 'Added Installation instructions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rits1272/Timeline-wave/commits/47237adf9869f0003f9458e2c094de6e38e03b88'}]},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778052',
#   'type': 'IssuesEvent',
#   'actor': {'id': 981088,
#    'login': 'duronrulez',
#    'display_login': 'duronrulez',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/duronrulez',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/981088?'},
#   'repo': {'id': 3445729,
#    'name': 'amphp/http-client',
#    'url': 'https://api.github.com/repos/amphp/http-client'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/amphp/http-client/issues/227',
#     'repository_url': 'https://api.github.com/repos/amphp/http-client',
#     'labels_url': 'https://api.github.com/repos/amphp/http-client/issues/227/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/amphp/http-client/issues/227/comments',
#     'events_url': 'https://api.github.com/repos/amphp/http-client/issues/227/events',
#     'html_url': 'https://github.com/amphp/http-client/issues/227',
#     'id': 532416987,
#     'node_id': 'MDU6SXNzdWU1MzI0MTY5ODc=',
#     'number': 227,
#     'title': 'Is there a way to track stats for requests?',
#     'user': {'login': 'duronrulez',
#      'id': 981088,
#      'node_id': 'MDQ6VXNlcjk4MTA4OA==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/981088?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/duronrulez',
#      'html_url': 'https://github.com/duronrulez',
#      'followers_url': 'https://api.github.com/users/duronrulez/followers',
#      'following_url': 'https://api.github.com/users/duronrulez/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/duronrulez/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/duronrulez/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/duronrulez/subscriptions',
#      'organizations_url': 'https://api.github.com/users/duronrulez/orgs',
#      'repos_url': 'https://api.github.com/users/duronrulez/repos',
#      'events_url': 'https://api.github.com/users/duronrulez/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/duronrulez/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 867181755,
#       'node_id': 'MDU6TGFiZWw4NjcxODE3NTU=',
#       'url': 'https://api.github.com/repos/amphp/http-client/labels/question',
#       'name': 'question',
#       'color': 'fef2c0',
#       'default': True,
#       'description': ''}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'kelunik',
#      'id': 2743004,
#      'node_id': 'MDQ6VXNlcjI3NDMwMDQ=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/2743004?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kelunik',
#      'html_url': 'https://github.com/kelunik',
#      'followers_url': 'https://api.github.com/users/kelunik/followers',
#      'following_url': 'https://api.github.com/users/kelunik/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kelunik/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kelunik/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kelunik/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kelunik/orgs',
#      'repos_url': 'https://api.github.com/users/kelunik/repos',
#      'events_url': 'https://api.github.com/users/kelunik/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kelunik/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'kelunik',
#       'id': 2743004,
#       'node_id': 'MDQ6VXNlcjI3NDMwMDQ=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/2743004?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kelunik',
#       'html_url': 'https://github.com/kelunik',
#       'followers_url': 'https://api.github.com/users/kelunik/followers',
#       'following_url': 'https://api.github.com/users/kelunik/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kelunik/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kelunik/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kelunik/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kelunik/orgs',
#       'repos_url': 'https://api.github.com/users/kelunik/repos',
#       'events_url': 'https://api.github.com/users/kelunik/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kelunik/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2019-12-04T03:02:13Z',
#     'updated_at': '2019-12-06T07:46:09Z',
#     'closed_at': '2019-12-06T07:46:09Z',
#     'author_association': 'NONE',
#     'body': "Guzzle has the on_stats handler for this: http://docs.guzzlephp.org/en/stable/request-options.html#on-stats\r\n\r\nDoes the http client has something similar, i've tried digging around but i couldnt find anything."}},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z',
#   'org': {'id': 8865682,
#    'login': 'amphp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/amphp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8865682?'}},
#  {'id': '11026778031',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 79880635,
#    'name': 'pinotnoir72/project',
#    'url': 'https://api.github.com/repos/pinotnoir72/project'},
#   'payload': {'ref': 'dependabot/bundler/puma-3.12.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778027',
#   'type': 'PushEvent',
#   'actor': {'id': 12152727,
#    'login': 'marzecm',
#    'display_login': 'marzecm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marzecm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12152727?'},
#   'repo': {'id': 226194307,
#    'name': 'marzecm/ngrx-playground',
#    'url': 'https://api.github.com/repos/marzecm/ngrx-playground'},
#   'payload': {'push_id': 4363253940,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/step1',
#    'head': 'c2e04b781a1d158e0b90d95abc3c8e5d744ef7c0',
#    'before': 'f9438c05944a060b378f5504121c749a9957eba5',
#    'commits': [{'sha': 'c2e04b781a1d158e0b90d95abc3c8e5d744ef7c0',
#      'author': {'email': 'marzec_m@yahoo.fr', 'name': 'mmarzec'},
#      'message': 'minimal store',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marzecm/ngrx-playground/commits/c2e04b781a1d158e0b90d95abc3c8e5d744ef7c0'}]},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778026',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 36697775,
#    'login': 'alexonishchenko',
#    'display_login': 'alexonishchenko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexonishchenko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36697775?'},
#   'repo': {'id': 225308490,
#    'name': 'dolgydmitry/netans',
#    'url': 'https://api.github.com/repos/dolgydmitry/netans'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/dolgydmitry/netans/issues/4',
#     'repository_url': 'https://api.github.com/repos/dolgydmitry/netans',
#     'labels_url': 'https://api.github.com/repos/dolgydmitry/netans/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/dolgydmitry/netans/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/dolgydmitry/netans/issues/4/events',
#     'html_url': 'https://github.com/dolgydmitry/netans/issues/4',
#     'id': 533801356,
#     'node_id': 'MDU6SXNzdWU1MzM4MDEzNTY=',
#     'number': 4,
#     'title': 'non-idempotent playbook lab_ios_config_acl_match.yml',
#     'user': {'login': 'alexonishchenko',
#      'id': 36697775,
#      'node_id': 'MDQ6VXNlcjM2Njk3Nzc1',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/36697775?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alexonishchenko',
#      'html_url': 'https://github.com/alexonishchenko',
#      'followers_url': 'https://api.github.com/users/alexonishchenko/followers',
#      'following_url': 'https://api.github.com/users/alexonishchenko/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alexonishchenko/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alexonishchenko/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alexonishchenko/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alexonishchenko/orgs',
#      'repos_url': 'https://api.github.com/users/alexonishchenko/repos',
#      'events_url': 'https://api.github.com/users/alexonishchenko/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alexonishchenko/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-06T07:45:07Z',
#     'updated_at': '2019-12-06T07:46:09Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': ''},
#    'comment': {'url': 'https://api.github.com/repos/dolgydmitry/netans/issues/comments/562469321',
#     'html_url': 'https://github.com/dolgydmitry/netans/issues/4#issuecomment-562469321',
#     'issue_url': 'https://api.github.com/repos/dolgydmitry/netans/issues/4',
#     'id': 562469321,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjQ2OTMyMQ==',
#     'user': {'login': 'alexonishchenko',
#      'id': 36697775,
#      'node_id': 'MDQ6VXNlcjM2Njk3Nzc1',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/36697775?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alexonishchenko',
#      'html_url': 'https://github.com/alexonishchenko',
#      'followers_url': 'https://api.github.com/users/alexonishchenko/followers',
#      'following_url': 'https://api.github.com/users/alexonishchenko/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alexonishchenko/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alexonishchenko/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alexonishchenko/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alexonishchenko/orgs',
#      'repos_url': 'https://api.github.com/users/alexonishchenko/repos',
#      'events_url': 'https://api.github.com/users/alexonishchenko/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alexonishchenko/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-06T07:46:09Z',
#     'updated_at': '2019-12-06T07:46:09Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'The problem is in line below\r\n`          - permit tcp 10.10.11.0 0.0.0.255 any eq 80`'}},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778024',
#   'type': 'WatchEvent',
#   'actor': {'id': 26522281,
#    'login': 'Wen-Wen-Luffy',
#    'display_login': 'Wen-Wen-Luffy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Wen-Wen-Luffy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26522281?'},
#   'repo': {'id': 168630156,
#    'name': 'facebookresearch/pyrobot',
#    'url': 'https://api.github.com/repos/facebookresearch/pyrobot'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z',
#   'org': {'id': 16943930,
#    'login': 'facebookresearch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/facebookresearch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16943930?'}},
#  {'id': '11026778019',
#   'type': 'PushEvent',
#   'actor': {'id': 3455449,
#    'login': 'Dids',
#    'display_login': 'Dids',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dids',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3455449?'},
#   'repo': {'id': 92093628,
#    'name': 'Didstopia/SDL',
#    'url': 'https://api.github.com/repos/Didstopia/SDL'},
#   'payload': {'push_id': 4363253930,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/SDL-ryan-multiple-audio-device',
#    'head': '0bcd7577a9e4adde1fd2a08a2ed375753ebb201b',
#    'before': '0bcd7577a9e4adde1fd2a08a2ed375753ebb201b',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z',
#   'org': {'id': 11643531,
#    'login': 'Didstopia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Didstopia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11643531?'}},
#  {'id': '11026778012',
#   'type': 'PushEvent',
#   'actor': {'id': 43069409,
#    'login': 'Doemuu',
#    'display_login': 'Doemuu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Doemuu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43069409?'},
#   'repo': {'id': 224371983,
#    'name': 'Doemuu/Remindotron',
#    'url': 'https://api.github.com/repos/Doemuu/Remindotron'},
#   'payload': {'push_id': 4363253922,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '25385f3bf22edf4f6e549e91a73380974656e99a',
#    'before': '2c7a6ff07baa67586bc9bcbb4e010d7746846e5f',
#    'commits': [{'sha': '25385f3bf22edf4f6e549e91a73380974656e99a',
#      'author': {'email': '43069409+Doemuu@users.noreply.github.com',
#       'name': 'Doemuu'},
#      'message': 'using f-string',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Doemuu/Remindotron/commits/25385f3bf22edf4f6e549e91a73380974656e99a'}]},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778021',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 96820911,
#    'name': 'cartothemax/rails_filter_example',
#    'url': 'https://api.github.com/repos/cartothemax/rails_filter_example'},
#   'payload': {'ref': 'dependabot/bundler/puma-3.12.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778006',
#   'type': 'PushEvent',
#   'actor': {'id': 35752790,
#    'login': 'Kody-Quintana',
#    'display_login': 'Kody-Quintana',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kody-Quintana',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35752790?'},
#   'repo': {'id': 209874936,
#    'name': 'JacobKohav/NuMem_Components',
#    'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components'},
#   'payload': {'push_id': 4363253924,
#    'size': 33,
#    'distinct_size': 33,
#    'ref': 'refs/heads/master',
#    'head': 'd5c5374169a67692a7b94271e83ae5de4e281cfb',
#    'before': '239b7606e035323d1954308b37883159d363d1cc',
#    'commits': [{'sha': '42c38ad89b8ab549a9f5bd75d5e4e0d6da37abbf',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody.Quintana'},
#      'message': 'Add TODO_1 goals',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/42c38ad89b8ab549a9f5bd75d5e4e0d6da37abbf'},
#     {'sha': '3c88b6d95ece843697a1fbfa4831a404e819f384',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nThis is the home page in html for a basis for the pages.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/3c88b6d95ece843697a1fbfa4831a404e819f384'},
#     {'sha': '635ee01abcfa2c0899180c826ce4f4410a04ee18',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Rename index.html to home_page.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/635ee01abcfa2c0899180c826ce4f4410a04ee18'},
#     {'sha': '448f4cc586046a35752d01e5d08da62e6e8f8b77',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Delete home_page.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/448f4cc586046a35752d01e5d08da62e6e8f8b77'},
#     {'sha': '31daca72a562f23ac201c52c55de9008748067a1',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nHome Page for basis of pages.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/31daca72a562f23ac201c52c55de9008748067a1'},
#     {'sha': '43e26e7010c6421cbcf63729edd7e697a6ad99c2',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody Quintana'},
#      'message': 'Add test files for TODO_1 3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/43e26e7010c6421cbcf63729edd7e697a6ad99c2'},
#     {'sha': 'e10e9bc8ace0692deb4970575b6c3c03c41cedc2',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody Quintana'},
#      'message': 'Add slideshow template\n\nNo longer uses ajax requst to load content of each slide\nNow each slide is included in page and shown with bootstrap carousel',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/e10e9bc8ace0692deb4970575b6c3c03c41cedc2'},
#     {'sha': 'a8452db68f850c21900a1cbab9110672389783d9',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nResources to include on the Resources Page.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/a8452db68f850c21900a1cbab9110672389783d9'},
#     {'sha': 'badc059c9c2ae39d85827d38dfbe029e9d035eb8',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nManual to Embed as a PDF.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/badc059c9c2ae39d85827d38dfbe029e9d035eb8'},
#     {'sha': '5d09fa550a8ffef81dc20db272483f7c0790a3e8',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Delete Resources.docx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/5d09fa550a8ffef81dc20db272483f7c0790a3e8'},
#     {'sha': 'e2fb0d61c279b834b0a730223780602ef1362da1',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nResources to include on the Resources page.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/e2fb0d61c279b834b0a730223780602ef1362da1'},
#     {'sha': 'f73ccaa696e90e371972d166139e2db802e14237',
#      'author': {'email': 'jacob.kohav@coloradoledu', 'name': 'Jacob Kohav'},
#      'message': 'Quiz Questions for Quiz Page',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/f73ccaa696e90e371972d166139e2db802e14237'},
#     {'sha': '347e868cf86e645a98d044879f33b89455467c2c',
#      'author': {'email': '54992551+dogplushies@users.noreply.github.com',
#       'name': 'Milo Boyer'},
#      'message': 'Add navbar html file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/347e868cf86e645a98d044879f33b89455467c2c'},
#     {'sha': '8a9c5ab30f244de1280db9845bf34684a5beb32a',
#      'author': {'email': '49699696+JacobKohav@users.noreply.github.com',
#       'name': 'Jacob Kohav'},
#      'message': 'Add files via upload\n\nLogin and Create Account Pages (linked to Server)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/8a9c5ab30f244de1280db9845bf34684a5beb32a'},
#     {'sha': '7efb7d8ec833663944e7bc07340f4fbf42a48ce4',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody Quintana'},
#      'message': 'Add django demo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/7efb7d8ec833663944e7bc07340f4fbf42a48ce4'},
#     {'sha': 'b62d68d497befedccd25550ec84a3c1acec688da',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody Quintana'},
#      'message': 'Add requirements.txt and tsite_venv.sh for starting python venv',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/b62d68d497befedccd25550ec84a3c1acec688da'},
#     {'sha': '003fe3d871fd4efb316558a09e1055d30d9b3cca',
#      'author': {'email': 'Quintana.Kody@gmail.com', 'name': 'Kody Quintana'},
#      'message': 'Update venv script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/003fe3d871fd4efb316558a09e1055d30d9b3cca'},
#     {'sha': 'cc3ee084e1262849584e95edfc52d52f79c84d7a',
#      'author': {'email': '54992551+dogplushies@users.noreply.github.com',
#       'name': 'Milo Boyer'},
#      'message': 'Add a few aesthetic changes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/cc3ee084e1262849584e95edfc52d52f79c84d7a'},
#     {'sha': '5c611151995a78e177fcdb55c276010f3e1ce7b5',
#      'author': {'email': '54992551+dogplushies@users.noreply.github.com',
#       'name': 'Milo Boyer'},
#      'message': 'Update homepage.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/5c611151995a78e177fcdb55c276010f3e1ce7b5'},
#     {'sha': '25a7937d23491954ab05d281b25866bbf93c8871',
#      'author': {'email': '54992551+dogplushies@users.noreply.github.com',
#       'name': 'Milo Boyer'},
#      'message': 'Add new media for homepage',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JacobKohav/NuMem_Components/commits/25a7937d23491954ab05d281b25866bbf93c8871'}]},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026778011',
#   'type': 'WatchEvent',
#   'actor': {'id': 32605273,
#    'login': 'xiatianshitiancai',
#    'display_login': 'xiatianshitiancai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiatianshitiancai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32605273?'},
#   'repo': {'id': 178146028,
#    'name': 'xiatianshitiancai/996.ICU',
#    'url': 'https://api.github.com/repos/xiatianshitiancai/996.ICU'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-06T07:46:09Z'},
#  {'id': '11026777999',
#   'type': 'IssuesEvent',
#   'actor': {'id': 42543535,
#    'login': 'TimeBoat',
#    'display_login': 'TimeBoat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TimeBoat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42543535?'},
#   'repo': {'id': 223624709,
#    'name': 'huoji120/Antivirus_R3_bypass_demo',
#    'url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo/issues/2',
#     'repository_url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo',
#     'labels_url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/huoji120/Antivirus_R3_bypass_demo/issues/2/events',
#     'html_url': 'https://github.com/huoji120/Antivirus_R3_bypass_demo/issues/2',
#     'id': 533801700,
#     'node_id': 'MDU6SXNzdWU1MzM4MDE3MDA=',
#     'number': 2,
#     'title': '火鸡！求问这个具体怎么用啊？',
#     'user': {'login': 'TimeBoat',
#      'id': 42543535,
#      'node_id': 'MDQ6VXNlcjQyNTQzNTM1',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/42543535?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TimeBoat',
#      'html_url': 'https://github.com/TimeBoat',
#      'followers_url': 'https://api.github.com/users/TimeBoat/followers',
#      'following_url': 'https://api.github.com/users/TimeBoat/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TimeBoat/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TimeBoat/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TimeBoat/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TimeBoat/orgs',
#      'repos_url': 'https://api.github.com/users/TimeBoat/repos',
#      'events_url': 'https://api.github.com/users/TimeBoat/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TimeBoat/received_events',
#      'type': 'User',
#      'site_admin': False},
# ...
#       'gists_url': 'https://api.github.com/users/FI18-Trainees/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FI18-Trainees/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FI18-Trainees/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FI18-Trainees/orgs',
#       'repos_url': 'https://api.github.com/users/FI18-Trainees/repos',
#       'events_url': 'https://api.github.com/users/FI18-Trainees/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/FI18-Trainees/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 185136771,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODUxMzY3NzE=',
#       'name': 'vvspy',
#       'full_name': 'FI18-Trainees/vvspy',
#       'private': False,
#       'owner': {'login': 'FI18-Trainees',
#        'id': 55536405,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NTM2NDA1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/55536405?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/FI18-Trainees',
#        'html_url': 'https://github.com/FI18-Trainees',
#        'followers_url': 'https://api.github.com/users/FI18-Trainees/followers',
#        'following_url': 'https://api.github.com/users/FI18-Trainees/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/FI18-Trainees/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/FI18-Trainees/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/FI18-Trainees/subscriptions',
#        'organizations_url': 'https://api.github.com/users/FI18-Trainees/orgs',
#        'repos_url': 'https://api.github.com/users/FI18-Trainees/repos',
#        'events_url': 'https://api.github.com/users/FI18-Trainees/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FI18-Trainees/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/FI18-Trainees/vvspy',
#       'description': 'simple python module for the VVS API (Verkehrsverbund Stuttgart)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/FI18-Trainees/vvspy',
#       'forks_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/forks',
#       'keys_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/teams',
#       'hooks_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/events',
#       'assignees_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/tags',
#       'blobs_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/languages',
#       'stargazers_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/subscription',
#       'commits_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/merges',
#       'archive_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/downloads',
#       'issues_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/deployments',
#       'created_at': '2019-05-06T06:29:25Z',
#       'updated_at': '2019-12-05T17:06:19Z',
#       'pushed_at': '2019-12-06T07:46:07Z',
#       'git_url': 'git://github.com/FI18-Trainees/vvspy.git',
#       'ssh_url': 'git@github.com:FI18-Trainees/vvspy.git',
#       'clone_url': 'https://github.com/FI18-Trainees/vvspy.git',
#       'svn_url': 'https://github.com/FI18-Trainees/vvspy',
#       'homepage': '',
#       'size': 112,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     'base': {'label': 'FI18-Trainees:master',
#      'ref': 'master',
#      'sha': '0449bc71ea280f91601f772e81c6937837c0c15a',
#      'user': {'login': 'FI18-Trainees',
#       'id': 55536405,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NTM2NDA1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/55536405?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/FI18-Trainees',
#       'html_url': 'https://github.com/FI18-Trainees',
#       'followers_url': 'https://api.github.com/users/FI18-Trainees/followers',
#       'following_url': 'https://api.github.com/users/FI18-Trainees/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/FI18-Trainees/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FI18-Trainees/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FI18-Trainees/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FI18-Trainees/orgs',
#       'repos_url': 'https://api.github.com/users/FI18-Trainees/repos',
#       'events_url': 'https://api.github.com/users/FI18-Trainees/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/FI18-Trainees/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 185136771,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODUxMzY3NzE=',
#       'name': 'vvspy',
#       'full_name': 'FI18-Trainees/vvspy',
#       'private': False,
#       'owner': {'login': 'FI18-Trainees',
#        'id': 55536405,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU1NTM2NDA1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/55536405?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/FI18-Trainees',
#        'html_url': 'https://github.com/FI18-Trainees',
#        'followers_url': 'https://api.github.com/users/FI18-Trainees/followers',
#        'following_url': 'https://api.github.com/users/FI18-Trainees/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/FI18-Trainees/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/FI18-Trainees/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/FI18-Trainees/subscriptions',
#        'organizations_url': 'https://api.github.com/users/FI18-Trainees/orgs',
#        'repos_url': 'https://api.github.com/users/FI18-Trainees/repos',
#        'events_url': 'https://api.github.com/users/FI18-Trainees/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FI18-Trainees/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/FI18-Trainees/vvspy',
#       'description': 'simple python module for the VVS API (Verkehrsverbund Stuttgart)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/FI18-Trainees/vvspy',
#       'forks_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/forks',
#       'keys_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/teams',
#       'hooks_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/events',
#       'assignees_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/tags',
#       'blobs_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/languages',
#       'stargazers_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/subscription',
#       'commits_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/merges',
#       'archive_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/downloads',
#       'issues_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FI18-Trainees/vvspy/deployments',
#       'created_at': '2019-05-06T06:29:25Z',
#       'updated_at': '2019-12-05T17:06:19Z',
#       'pushed_at': '2019-12-06T07:46:07Z',
#       'git_url': 'git://github.com/FI18-Trainees/vvspy.git',
#       'ssh_url': 'git@github.com:FI18-Trainees/vvspy.git',
#       'clone_url': 'https://github.com/FI18-Trainees/vvspy.git',
#       'svn_url': 'https://github.com/FI18-Trainees/vvspy',
#       'homepage': '',
#       'size': 112,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls/35'},
#      'html': {'href': 'https://github.com/FI18-Trainees/vvspy/pull/35'},
#      'issue': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/35'},
#      'comments': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/issues/35/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls/35/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/pulls/35/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/FI18-Trainees/vvspy/statuses/df42bb451281bf02563b86e38792694694a9c70b'}},
#     'author_association': 'MEMBER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'Monkmitrad',
#      'id': 33026966,
#      'node_id': 'MDQ6VXNlcjMzMDI2OTY2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/33026966?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Monkmitrad',
#      'html_url': 'https://github.com/Monkmitrad',
#      'followers_url': 'https://api.github.com/users/Monkmitrad/followers',
#      'following_url': 'https://api.github.com/users/Monkmitrad/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Monkmitrad/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Monkmitrad/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Monkmitrad/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Monkmitrad/orgs',
#      'repos_url': 'https://api.github.com/users/Monkmitrad/repos',
#      'events_url': 'https://api.github.com/users/Monkmitrad/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Monkmitrad/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 8,
#     'additions': 17,
#     'deletions': 11,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2019-12-06T07:46:08Z',
#   'org': {'id': 55536405,
#    'login': 'FI18-Trainees',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FI18-Trainees',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55536405?'}}]

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0'},
#  'origin': '36.225.178.170, 36.225.178.170',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
#    'text': 'Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'More than half of the world’s felines don’t respond to catnip.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de7808a0013130015a3ccb0',
#    'type': 'cat',
#    'text': 'The wealthiest cat in the world is named Blackie.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780a00013130015a3ccb1',
#    'type': 'cat',
#    'text': 'A group of kittens is called a Kindle.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780d30013130015a3ccb2',
#    'type': 'cat',
#    'text': 'In October 1983, a cat named "Félicette" became the first cat in space.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780e60013130015a3ccb3',
#    'type': 'cat',
#    'text': 'Cats can be allergic to humans.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 32.26},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 79.44},
#   {'StationIdentifier': '2370H024',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 195.46},
#   {'StationIdentifier': '1510H063',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 263.89},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 6, 2019 3:50:00 PM',
#    'WaterLevel': 0.42},
#   {'StationIdentifier': '1510H050',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 155.69},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 69.08},
#   {'StationIdentifier': '1430H057',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 31.82},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 20.88},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 245.48},
#   {'StationIdentifier': '2420H037',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 133.4},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 173.24},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 48.29},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 140.96},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 124.09},
#   {'StationIdentifier': '1730H058',
#    'RecordTime': 'Dec 6, 2019 3:50:00 PM',
#    'WaterLevel': 113.8},
#   {'StationIdentifier': '2200H028',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 278.12},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.38},
#   {'StationIdentifier': '1430H048',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 166.09},
#   {'StationIdentifier': '1430H032',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 337.59},
#   {'StationIdentifier': '2200H021',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 369.68},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.15},
#   {'StationIdentifier': '1650H014',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 1.01},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 25.83},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 207.6},
#   {'StationIdentifier': '1430H046',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 111.14},
#   {'StationIdentifier': '1730H076',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 58.08},
#   {'StationIdentifier': '1540H031',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 10.26},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 23.75},
#   {'StationIdentifier': '1630H037',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 9.35},
#   {'StationIdentifier': '1630H020',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 35.3},
#   {'StationIdentifier': '1630H013',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 15.56},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 145.07},
#   {'StationIdentifier': '1730H071',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 35.35},
#   {'StationIdentifier': '1540H014',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 8.15},
#   {'StationIdentifier': '1430H025',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 10.29},
#   {'StationIdentifier': '1430H044',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 139.51},
#   {'StationIdentifier': '1590H019',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 14.92},
#   {'StationIdentifier': '1580H020',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 35.83},
#   {'StationIdentifier': '1510H081',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 229.11},
#   {'StationIdentifier': '1730H067',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 428.65},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Dec 4, 2019 5:50:00 PM',
#    'WaterLevel': 196.52},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 25.75},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 11.28},
#   {'StationIdentifier': '1580H013',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 9.86},
#   {'StationIdentifier': '1510H057',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 88.55},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 752.43},
#   {'StationIdentifier': '1290H004',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 115.81},
#   {'StationIdentifier': '1140H107',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 3.94},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 26.86},
#   {'StationIdentifier': '1590H012',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 2.92},
#   {'StationIdentifier': '1550H018',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.45},
#   {'StationIdentifier': '1550H011',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': -0.07},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 4.91},
#   {'StationIdentifier': '1140H098',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 175.05},
#   {'StationIdentifier': '1140H101',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 182.53},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 264.95},
#   {'StationIdentifier': '1580H007',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 23.75},
#   {'StationIdentifier': '1140H076',
#    'RecordTime': 'Dec 6, 2019 4:00:00 PM',
#    'WaterLevel': 135.96},
#   {'StationIdentifier': '1540H038',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 54.82},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 25},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 3.87},
#   {'StationIdentifier': '1540H036',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1350H019',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 33.76},
#   {'StationIdentifier': '1430H038',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 75.53},
#   {'StationIdentifier': '1140H048',
#    'RecordTime': 'Dec 6, 2019 4:00:00 PM',
#    'WaterLevel': 29.05},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 23.56},
#   {'StationIdentifier': '1430H060',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 20.34},
#   {'StationIdentifier': '1660H013',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 1.02},
#   {'StationIdentifier': '1420H052',
#    'RecordTime': 'Dec 6, 2019 4:00:00 PM',
#    'WaterLevel': 429.59},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 247.17},
#   {'StationIdentifier': '1650H011',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.32},
#   {'StationIdentifier': '2560H024',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 202.85},
#   {'StationIdentifier': '1510H088',
#    'RecordTime': 'Dec 6, 2019 4:00:00 PM',
#    'WaterLevel': 141.1},
#   {'StationIdentifier': '1430H055',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 78.6},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 87.7},
#   {'StationIdentifier': '1350H030',
#    'RecordTime': 'Dec 6, 2019 3:50:00 PM',
#    'WaterLevel': 57.62},
#   {'StationIdentifier': '1340H010',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.79},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Dec 6, 2019 4:00:00 PM',
#    'WaterLevel': 471.7},
#   {'StationIdentifier': '2560H022',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 194.58},
#   {'StationIdentifier': '1510H085',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 279.86},
#   {'StationIdentifier': '1300H024',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 29.08},
#   {'StationIdentifier': '1650H006',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 1.31},
#   {'StationIdentifier': '1350H028',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 232.83},
#   {'StationIdentifier': '1300H021',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.25},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 318.68},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 4.64},
#   {'StationIdentifier': '1400H008',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 479.66},
#   {'StationIdentifier': '1340H009',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 176.02},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Dec 6, 2019 3:20:00 PM',
#    'WaterLevel': 402.49},
#   {'StationIdentifier': '1350H026',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 30.41},
#   {'StationIdentifier': '1300H017',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 27.03},
#   {'StationIdentifier': '1400H018',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 55.24},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 0.24},
#   {'StationIdentifier': '1350H021',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 320.62},
#   {'StationIdentifier': '1310H002',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 1.18},
#   {'StationIdentifier': '1630H026',
#    'RecordTime': 'Dec 6, 2019 3:50:00 PM',
#    'WaterLevel': 44.52},
#   {'StationIdentifier': '1350H023',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 256.36},
#   {'StationIdentifier': '1140H127',
#    'RecordTime': 'Dec 6, 2019 4:10:00 PM',
#    'WaterLevel': 33.81}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
